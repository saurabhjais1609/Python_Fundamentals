# %%
# f-String
# Syntax
# f"{variable/expression}"

# %%
first_name = "Saurabh"
last_name = "Jaiswal"
full_name = f"{first_name} {last_name}"
print(full_name)
# Out:
# Saurabh Jaiswal

# %%
message = f"Keep up the good work, {full_name}!"
print(message)
# Out:
# Keep up the good work, Saurabh Jaiswal!

# %%
# Whitespace
# \n --> New line delimiter
# \t --> Tab delimiter

# %%
print("Favorite Programming Language:\nPython\nJavaScript\nJava")
# Out:
# Favorite Programming Language:
# Python
# JavaScript
# Java

# %%
print("Web Development:\nFrontend:\nHTML\tCSS\tJavaScript\tReact\nBackend:\nNodeJS\tExpress\nDatabase\nMongoDB\tOracleSQL")
# Out:
# Web Development:
# Frontend:
# HTML	CSS	JavaScript	React
# Backend:
# NodeJS	Express
# Database
# MongoDB	OracleSQL

# %%
# Eliminating Whitespace
# lstrip(), rstrip()

# %%
prog_lang = "  Python"
print(prog_
