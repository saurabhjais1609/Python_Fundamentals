# %%
# Variables in Python

# %%
a = 2
b = 3
c = a + b
print(c)
# Out:
# 5

# %%
# Rules for declaring the variables in Python
# 1. No Namespaces while declaring the variable name

# %%
first name = "Saurabh"
# Out:
#   Cell In[4], line 1
#     first name = "Saurabh"
#           ^
# SyntaxError: invalid syntax

# %%
# 2. A variable name should not start with a number **

# %%
1name = "Rushali"
# Out:
#   Cell In[5], line 1
#     1name = "Rushali"
#     ^
# SyntaxError: invalid decimal literal

# %%
# 3. A variable name should not contain any special characters @ # $ % ^ & * ( ) except _

# %%
@name = "Radhika"
# Out:
#   Cell In[6], line 1
#     @name = "Radhika"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
first_name = "Goldi"
print(first_name)
# Out:
# Goldi

# %%
# Datatypes in Python    
#   1. strings -----> str
#   2. Numbers -----> integers ---( int) and float ( decimals --- 0.1,0.2)
#   3. list
#   4. tuple
#   5. dictionary -------> dict

# %%
# Classification of datatypes
# Broadly datatypes are classified in to 2 categeories :
# 1. mutable  ---> which can edit/ alter ----flexible in nature
# 2. immutable -----> which we cannot edit / alter - fixed in nature

# %%
# String
# Defination : A string is nothing but a squence of characters written in quotes.
# Classification : it is classfied as an immutable datatype   
# how do you declare the string
# 1. approach - 1 : using single quote    
# 2. approach - 2 : using double quote

# %%
name = "Radhika"
print(name);
# Out:
# Radhika

# %%
#String Methods
#type(), title(), lower(), upper()

# %%
type(name)
# Out:
# str

# %%
fullname = "radhika shrikant jaju"
print(fullname)
print(fullname.title())
print(fullname.upper())
print(fullname.lower())
# Out:
# radhika shrikant jaju
# Radhika Shrikant Jaju
# RADHIKA SHRIKANT JAJU
# radhika shrikant jaju
